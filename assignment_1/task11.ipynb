# %%
from IPython.display import Image

Image("images/photo_5350494331657645208_y.jpg")

# %%
Image("images/photo_5467848729563363437_y.jpg")

# %%
Image("images/photo_5467848729563363438_y.jpg")

# %%
Image("images/photo_5467848729563363439_y.jpg")
