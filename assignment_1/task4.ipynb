# %%
from IPython.display import Image

Image("images/photo_5350494331657645193_y.jpg")

# %%
Image("images/photo_5406847798684545245_y.jpg")

# %%
Image("images/photo_5406847798684545246_y.jpg")

# %%
Image("images/photo_5406847798684545247_y.jpg")
