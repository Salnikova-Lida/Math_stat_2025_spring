# %%
from IPython.display import Image

Image("images/photo_5350494331657645212_y.jpg")

# %%
Image("images/photo_5350494331657645213_y.jpg")

# %%
Image("images/photo_5467848729563363441_y.jpg")

# %%
Image("images/photo_5467848729563363440_y.jpg")
