# %%
from IPython.display import Image

Image("images/photo_5350494331657645182_y.jpg")

# %%
Image("images/photo_5354997931285014404_y.jpg")

# %%
Image("images/photo_5354997931285014405_y.jpg")

# %%
Image("images/photo_5355165568153546655_y.jpg")

# %%
Image("images/photo_5355165568153546656_y.jpg")
