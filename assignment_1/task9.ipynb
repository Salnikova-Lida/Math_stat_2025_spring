# %%
from IPython.display import Image

Image("images/photo_5350278556795665966_y.jpg")

# %%
Image("images/photo_5350494331657645205_y.jpg")

# %%
Image("images/photo_5427352127174470324_y.jpg")

# %%
Image("images/photo_5427352127174470325_y.jpg")
