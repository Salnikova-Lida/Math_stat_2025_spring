# %%
from IPython.display import Image

Image("images/photo_5350494331657645189_y.jpg")

# %%
Image("images/photo_5363825699691035153_y.jpg")

# %%
Image("images/photo_5363825699691035154_y.jpg")

# %%
Image("images/photo_5363825699691035155_y.jpg")
